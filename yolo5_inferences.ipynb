# %% [markdown]
# # YOLO 5 INFERENCE CON BBOX#

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.10.12 torch-2.0.1+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/107.7 GB disk)

# %%
# !python detect.py --weights /content/best.pt --conf 0.7 --source /content/datos2
# Out:
# detect: weights=['/content/best.pt'], source=/content/datos2, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.7, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/141 /content/datos2/pagina2ABGHUhVVlHGTPwIQUFEne2AgkVK-uAC6Dv9SMg.jpg: 480x640 1 ['per'], 278.1ms
# image 2/141 /content/datos2/pagina2ABGHUhVWBhJoHwIQ7Z3u9pj6gE8_TruWtUV4-Q.jpg: 640x512 1 ['per'], 1 ['sec'], 294.6ms
# ...

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import cv2
import time
exp = 'exp' #ambiar segun el experimento 2
carpeta = Path('/content/yolov5/runs/detect/{}'.format(exp))
h=0
for file in carpeta.iterdir():
  name = file.name
  print("NOMBRE DOC:",name)
  k=cv2.imread('/content/yolov5/runs/detect/{}/{}'.format(exp,name))
  k=cv2.cvtColor(k,cv2.COLOR_BGR2RGB)
  plt.figure(figsize=(8,6))
  plt.imshow(k)
  plt.show()
  if h==50:
    break
  h=h+1

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import cv2
import time
exp = 'exp2' #ambiar segun el experimento 2
carpeta = Path('/content/yolov5/runs/detect/{}'.format(exp))
for file in carpeta.iterdir():
  name = file.name
  print("NOMBRE DOC:",name)
  k=cv2.imread('/content/yolov5/runs/detect/{}/{}'.format(exp,name))
  k=cv2.cvtColor(k,cv2.COLOR_BGR2RGB)
  plt.figure(figsize=(10,8))
  plt.imshow(k)
  plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #INFERENCE CON SEGMENTACION ##

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-132-ga82132c Python-3.9.16 torch-1.13.1+cu116 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.7/107.7 GB disk)

# %%
# !python segment/predict.py --weights /content/best_200epo.pt --conf 0.50 --source /content/datos3
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import cv2
import time
exp = 'exp' #ambiar segun el experimento 2
carpeta = Path('/content/yolov5/runs/predict-seg/{}'.format(exp))
for file in carpeta.iterdir():
  name = file.name
  print("NOMBRE DOC:",name)
  k=cv2.imread('/content/yolov5/runs/predict-seg/{}/{}'.format(exp,name))
  k=cv2.cvtColor(k,cv2.COLOR_BGR2RGB)
  plt.figure(figsize=(12,12))
  plt.imshow(k)
  plt.show()
# Out:
# NOMBRE DOC: e1e6a20c-8636d1a2-tm31.jpeg
# NOMBRE DOC: fb3221eb-o1.png
# NOMBRE DOC: ff92827f-945c8c0a-d04647da-17e3-11ed-b79c-02321d83b54a_1.jpeg
# NOMBRE DOC: f8fbb453-u4.png
# NOMBRE DOC: Captura de pantalla 2023-03-31 103558.png
# NOMBRE DOC: fb5387ee-12481dd1-cardio1.jpeg
# NOMBRE DOC: fdf6f5cf-8601907b-tw19.jpeg
# NOMBRE DOC: f072345c-083dd587-table21.JPG
# NOMBRE DOC: Captura de pantalla 2023-03-31 103530.png
# NOMBRE DOC: fb24c17f-u17.png
# NOMBRE DOC: f38d322c-2ec0d192-ta14.jpeg
# NOMBRE DOC: ed6fc44c-807262c5-1_6.jpeg
# NOMBRE DOC: ed203c86-u19.png
